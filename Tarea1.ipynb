# %% [markdown]
# **INTRODUCCION A PYTHON**
#
# JHON JAIRO CASTILLO
#
# 2167742

# %% [markdown]
# ##**OPERADORES BASICOS**

# %%
import numpy as np
u=np.array([1,0,3,0,-2])
v=np.array([1,3,0,1,0])
s=u.dot(v)
print(s)
# Out:
# 1

# %% [markdown]
# -----------------------
#
# 1. Escriba un programa que solicite al usuario que escriba su nombre, y lo salude llamándolo por su nombre.

# %%
nombre= input("ingrese su nombre: ")
print("Hola ", nombre)
# Out:
# ingrese su nombre: John
# Hola  John

# %% [markdown]
# ---------------------
# 2. Realice un programa que calcule el promedio de 4 notas ingresadas por el usuario

# %%
nota1= float(input("ingrese la primera nota "))
nota2= float(input("ingrese la segunda nota "))
nota3= float(input("ingrese la tercera nota "))
nota4= float(input("ingrese la cuarta nota "))

prom=(nota1+nota2+nota3+nota4)/4

print("El promedio es: ", prom)
# Out:
# ingrese la primera nota 3.7
# ingrese la segunda nota 3.8
# ingrese la tercera nota 3.9
# ingrese la cuarta nota 4.0
# El promedio es:  3.85

# %% [markdown]
# -------------------
# 3. Desarrolle un programa que convierta de centímetros a pulgadas. Una pulgada es igual a 2.54 centímetros.

# %%
centimetros= float(input("ingrese la medida en centimetros "))
pulgadas= centimetros/2.54

print(centimetros, "cm equivalen a ",pulgadas , "pulgadas")
# Out:
# ingrese la medida en centimetros 100
# 100.0 cm equivalen a  39.37007874015748 pulgadas

# %% [markdown]
# -------------
# 4. Escriba un programa que reciba como entrada las longitudes de los dos catetos a y b de un triángulo
# rectángulo, y que entregue como salida el largo de la hipotenusa c del triángulo, dado por el teorema de
# Pitágoras: c
# 2 = a
# 2 + b
# 2

# %%
import math
a= float(input("ingrese el valor del cateto 1: "))
b= float(input("ingrese el valor del cateto 2: "))

c = math.sqrt(a**2+b**2)

print("la hipotenusa es: ",c)
# Out:
# ingrese el valor del cateto 1: 3
# ingrese el valor del cateto 2: 4
# la hipotenusa es:  5.0

# %% [markdown]
# ----------------------
# 5. Implemente un programa que reciba como entrada el radio de un círculo y entregue como salida su
# perímetro y su área.

# %%
from math import pi
radio=float(input("Ingrese el radio del circulo: "))

perimetro= 2*pi*radio
area= pi*radio**2

print("El perimetro del circulo es: ",perimetro,"unidades")
print("El area del circulo es: ", area,"unidades^2")
# Out:
# Ingrese el radio del circulo: 3
# El perimetro del circulo es:  18.84955592153876 unidades
# El area del circulo es:  28.274333882308138 unidades^2

# %% [markdown]
# ##**ESTRUCTURAS CONDICIONALES**

# %% [markdown]
# ----------------------
# 1. Escriba un programa que reciba como entrada dos números, y los muestre ordenados de menor a mayor

# %%
num1= int(input("ingrese primer numero: "))
num2= int(input("ingrese segundo numero: "))

if num1> num2:
  print("el orden es: ",num1, num2)
else:
  print("el orden es: ",num2,num1)
# Out:
# ingrese primer numero: 1
# ingrese segundo numero: 5
# el orden es:  5 1

# %% [markdown]
# -------------------
# 2. Realice un programa que simule una calculadora básica, este puede realizar operación de suma, resta,
# multiplicación y división. El programa debe recibir como entrada 2 números reales y un operador, que
# puede ser +, −, ∗, /. La salida del programa debe ser el resultado de la operación.

# %%
num1= float(input("ingrese primer numero: "))
num2= float(input("ingrese segundo numero: "))

oper= input("Ingrese el operador de la operacion que desea realizar(+,-,*,/): ")

if oper=="+":
  res=num1+num2

elif oper == "-":
    res=num1-num2
elif oper == "*":
   res= num1*num2
elif oper == "/":
    res=num1/num2
else:
    print("ingrese un operador")

print("el resultado es", res)
# Out:
# ingrese primer numero: 8
# ingrese segundo numero: 2
# Ingrese el operador de la operacion que desea realizar(+,-,*,/): /
# el resultado es 4.0

# %% [markdown]
# ---------------
# 3. El riesgo de que una persona sufra enfermedades coronarias depende de su edad y su índice de masa
# corporal:
# ![image.png](data:image/png;base64,...)
#
# El índice de masa corporal es el cociente entre el peso del individuo en kilos y el cuadrado de su estatura
# en metros. Escriba un programa que reciba como entrada la estatura, el peso y la edad de una persona,
# y le entregue su condición de riesgo.

# %%
edad=int(input("ingrese su edad: "))
peso=float(input("ingrese su peso: "))
estatura=float(input("ingrese su estatura en metros: "))

IMC=peso/estatura**2
print("su indice de masa corporal es: ",IMC)

if edad < 45:
  if IMC>=22:
    print("su riesgo de sufrir una enfermedad coronaria es medio")
  else:
    print("su riesgo de sufrir una enfermedad coronaria es bajo")
else:
   if IMC>=22:
    print("su riesgo de sufrir una enfermedad coronaria es alto")
   else:
    print("su riesgo de sufrir una enfermedad coronaria es medio")
# Out:
# ingrese su edad: 25
# ingrese su peso: 58
# ingrese su estatura en metros: 1.60
# su indice de masa corporal es:  22.656249999999996
# su riesgo de sufrir una enfermedad coronaria es medio

# %% [markdown]
# ##**CICLOS**

# %% [markdown]
# 1. Escriba un programa que muestre la tabla de multiplicar del 1 al 10 del número ingresado por el usuario

# %%
num=int(input("Ingrese el numero del que desea la tabla de multiplicar: "))

for i in range (1,11):
  res=num*i
  print(num,"*",i,"=",res)
# Out:
# Ingrese el numero del que desea la tabla de multiplicar: 3
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
# 3 * 10 = 30

# %% [markdown]
# ------------
# 2. Escriba un programa que pida al usuario dos números enteros, y luego entregue la suma de todos los
# números que están entre ellos. Por ejemplo, si los números son 1 y 7, debe entregar como resultado
# 2 + 3 + 4 + 5 + 6 = 20.

# %%
a=int(input("Ingrese el numero menor entero para realizar la suma: "))
b=int(input("Ingrese el numero mayor entero para realizar la suma: "))

res=0

for i in range(a+1,b):
  res+=i
  print(res)

print("el valor de la suma es: ",res)
# Out:
# Ingrese el numero menor entero para realizar la suma: 4
# Ingrese el numero mayor entero para realizar la suma: 10
# 5
# 11
# 18
# 26
# 35
# el valor de la suma es:  35

# %%
import matplotlib as plt
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
Z=X**2+Y**2

figure = plt.figure(1, figsize = (12, 4))
subplot3d = plt.subplot(111, projection='3d')
surface = subplot3d.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=matplotlib.cm.coolwarm, linewidth=0.1)
plt.show()

# %%
Z1=X+Y

figure = plt.figure(1, figsize = (12, 4))
subplot3d = plt.subplot(111, projection='3d')
surface = subplot3d.plot_surface(X, Y, Z1, rstride=1, cstride=1, cmap=matplotlib.cm.coolwarm, linewidth=0.1)
plt.show()

# %%
Z2=X**2+Y

figure = plt.figure(1, figsize = (12, 4))
subplot3d = plt.subplot(111, projection='3d')
surface = subplot3d.plot_surface(X, Y, Z2, rstride=1, cstride=1, cmap=matplotlib.cm.coolwarm, linewidth=0.1)
plt.show()

# %%
Z3=np.sqrt(X**2+Y**2)

figure = plt.figure(1, figsize = (12, 4))
subplot3d = plt.subplot(111, projection='3d')
surface = subplot3d.plot_surface(X, Y, Z3, rstride=1, cstride=1, cmap=matplotlib.cm.coolwarm, linewidth=0.1)
plt.show()

# %%
Z4=np.sqrt(1-X**2-Y**2)

figure = plt.figure(1, figsize = (12, 4))
subplot3d = plt.subplot(111, projection='3d')
surface = subplot3d.plot_surface(X, Y, Z4, rstride=1, cstride=1, cmap=matplotlib.cm.coolwarm, linewidth=0.1)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in sqrt
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   """

# %%
import matplotlib as plt
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

x=np.linspace(-4,6,500)
y=-x**3+3*x**2+9*x+10

plt.plot(x,y)
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show>
